# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from openai import OpenAI
from IPython.display import Markdown, display

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the student bring a ladder to their LLM engineering class?
#
# Because they heard it was all about **scaling up** models!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one for you:
#
# **Why did the LLM engineer break up with their model?**
#
# Because it kept hallucinating about their future together, the context window was too small for a long-term relationship, and every time they had an argument, it would just forget everything after 4096 tokens.
#
# *Plus, it turns out "I love you" was just the statistically most likely next token given their conversation history.* 😅
#
# ---
#
# Bonus dad joke:
#
# **What's an LLM engineer's favorite exercise?**
#
# *Weight training.*
#
# (You'll get really good at it around epoch 3!)

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Assume the books are arranged in order: [Volume 1] [Volume 2], with covers and pages as follows for each volume:
# - Pages thickness: 2 cm per volume
# - Each cover thickness: 2 mm = 0.2 cm
# - A standard arrangement front to back: cover, pages, cover
#
# When the worm gnaws perpendicular to the pages from the first page of Volume 1 to the last page of Volume 2, it traverses the material along a straight line through the intervening objects in a single direction.
#
# Consider the distance from the very first page of Volume 1 to the very last page of Volume 2, measured along the book stack. The worm starts at the first page of Volume 1 (i.e., at the inner boundary facing Volume 1, after the front cover of Volume 1) and ends at the last page of Volume 2 (i.e., at the boundary just before the back cover of Volume 2).
#
# Key distances to account for:
# - The worm does not need to pass through the front cover of Volume 1 (it starts at the first page).
# - It does need to pass through the entire pages of Volume 1 (2 cm) and through the space between Volume 1 and Volume 2 (i.e., the back cover of Volume 1 and the front cover of Volume 2, plus any gap between the volumes if present). However, since the volumes are side by side with their covers touching, the boundary between them is the back cover of Volume 1 and the front cover of Volume 2.
#
# Similarly, the worm ends at the last page of Volume 2, which is just inside the back cover, so it does not pass through the back cover of Volume 2.
#
# Thus total distance gnawed:
# - Through Volume 1 pages: 2 cm
# - Through back cover of Volume 1 and front cover of Volume 2: 0.2 cm + 0.2 cm = 0.4 cm
# - Through Volume 2 pages up to the last page: 2 cm
#
# Sum = 2 cm + 0.4 cm + 2 cm = 4.4 cm
#
# Answer: 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and how they're structured.
#
# **Key observations:**
#
# 1) When books stand on a shelf in reading order (spine facing out), Volume 1 is on the left and Volume 2 is on the right.
#
# 2) For a book standing normally on a shelf:
#    - The FIRST page of a volume is on the RIGHT side (near Volume 2)
#    - The LAST page of a volume is on the LEFT side (near Volume 1)
#
#    This is because when you open a book, page 1 starts on the right side.
#
# 3) Each book has:
#    - Front cover (2 mm)
#    - Pages (2 cm = 20 mm)
#    - Back cover (2 mm)
#
# **The worm's path:**
#
# The worm goes from the first page of Volume 1 to the last page of Volume 2.
#
# - **First page of Volume 1**: This is on the RIGHT side of Volume 1 (the side touching Volume 2)
# - **Last page of Volume 2**: This is on the LEFT side of Volume 2 (the side touching Volume 1)
#
# So the worm's path goes:
# 1. Starting at the first page of Volume 1 (right side of Volume 1)
# 2. Through the back cover of Volume 1 (2 mm)
# 3. Through the front cover of Volume 2 (2 mm)
# 4. Ending at the last page of Volume 2 (left side of Volume 2)
#
# The worm does NOT go through the pages of either volume!
#
# **Total distance: 2 mm + 2 mm = 4 mm**
#
# The answer is **4 mm** (or **0.4 cm**).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf with spines facing out and volumes in order, the first page of Volume 1 lies just inside its front cover (on the right side), and the last page of Volume 2 lies just inside its back cover (on the left side). These two covers face each other. So the worm passes only through the two covers: 2 mm + 2 mm = 4 mm (0.4 cm).

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on our assumptions about how books are arranged on a shelf. Here is the step-by-step solution:
#
# 1.  **Visualize the books:** The two volumes are standing side-by-side in the correct order. Volume 1 is on the left, and Volume 2 is on the right.
#
#     ```
#     +---------+ +---------+
#     |         | |         |
#     |    V1   | |    V2   |
#     |         | |         |
#     +---------+ +---------+
#     SHELF
#     ```
#
# 2.  **Identify the components:** Let's break down the books into their parts from left to right on the shelf:
#     *   **Volume 1:** Front Cover, Pages, Back Cover.
#     *   **Volume 2:** Front Cover, Pages, Back Cover.
#
# 3.  **Locate the start and end points:** This is the crucial part of the riddle.
#     *   The worm starts at the **first page of Volume 1**. When a book is on a shelf, its first page is on the right side of the text block, immediately inside the front cover.
#     *   The worm ends at the **last page of Volume 2**. The last page is on the left side of its text block, immediately inside the back cover.
#
#     Let's visualize the exact positions:
#
#
#
# 4.  **Trace the worm's path:**
#     *   The worm starts at the first page of Volume 1. Because the books are side-by-side, this starting point is right next to the back cover of Volume 1.
#     *   It ends at the last page of Volume 2. This ending point is right next to the front cover of Volume 2.
#     *   The worm only needs to travel through the two covers that are in between these two pages.
#
# 5.  **Calculate the distance:** The worm gnaws through:
#     *   The back cover of Volume 1 (2 mm)
#     *   The front cover of Volume 2 (2 mm)
#
# The total distance is 2 mm + 2 mm = **4 mm**.
#
# The information about the thickness of the pages (2 cm) is there to distract you. The worm doesn't go through the pages of either volume.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""
3
dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, the rational cooperative strategy is to Share. If I assume my partner is thinking logically:
#
# - Mutual cooperation (Share/Share) guarantees us both $1,000
# - Mutual defection (Steal/Steal) gives us both $0
# - The asymmetric outcome depends on predicting the other's choice
#
# Since we both face the same incentives and presumably want to avoid the $0 outcome, and since $1,000 is a solid guaranteed win versus the risk of walking away with nothing, **Share** is the choice that balances trust with rationality. It's the only outcome where we both benefit.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**.  Even though “Steal” can give a higher payoff if the other player cooperates, it also risks ending up with nothing if they also choose “Steal.”  By sharing, the best‑case outcome ($1,000 each) is guaranteed as long as the other person also shares, and there’s no chance of walking away empty‑handed.  So I’d go with the cooperative option.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.
#
# (Rationale: In this one-shot Prisoner's Dilemma setup, stealing is the dominant strategy—it maximizes my potential payout regardless of what my partner chooses, even though it risks us both getting nothing if they also steal.)

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is like a cool, refreshing feeling you might get from the vast, clear sky on a sunny day, or the deep, calm expanse of the ocean.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the cool, calm feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water on a hot day.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailor-made for an aspiring LLM Engineer, playing on the daily grind and quirks of working with large language models:
#
# **Why did the LLM Engineering student bring a blanket and pillow to their prompt engineering session?**
#
# **Because they heard they needed to work on "bedrock" models!** 🛌🪨
#
# *(Bonus groan-worthy follow-up punchline for extra credit):*
# *And honestly, they were exhausted from debugging hallucinations all night... again.* 😴👻
#
# ---
#
# **Why it's funny for an LLM Engineering student:**
#
# 1.  **"Bedrock" Models:** References AWS Bedrock and other foundational model platforms – a core part of the LLM engineer's toolkit. It puns the literal meaning (rock/earth) with the technical meaning.
# 2.  **Prompt Engineering:** This is *the* essential skill. Students spend countless hours crafting, testing, and refining prompts to get the desired output. It's central to their journey.
# 3.  **The Struggle is Real:** Mentioning debugging hallucinations taps directly into a major, frustrating challenge in LLM development – models making plausible-sounding but untrue statements. It's a shared pain point.
# 4.  **Sleep Deprivation:** A universal student experience, amplified for anyone debugging complex AI systems late into the night.
# 5.  **Inside Baseball:** It uses terminology ("bedrock," "prompt engineering," "hallucinations") that is instantly recognizable to someone on this learning path, making it feel like an "insider" joke.
#
# It perfectly captures the blend of cutting-edge tech, tedious work, and constant problem-solving that defines the journey to LLM expertise. Now, back to fine-tuning those parameters! 😉

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# 1) Why did the LLM-engineering student bring a ladder to the lab?
# They heard they needed to scale the model to become an expert.
#
# 2) Mentor: "How do you become an LLM engineering expert?"
# Student: "Easy — just reduce the learning rate, increase the epochs, and hope your ego doesn't overfit."
#
# 3) How do you know an LLM-engineering student is progressing?
# Their prompts go from "please explain" → "explain step-by-step" → "explain with sources and code," and their sleep schedule becomes a hyperparameter.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student refuse to cross the road?
#
# Because they didn't have enough training data on successful crossings, and were worried about overfitting to chicken jokes!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 36
# Total tokens: 60
# Total cost: 0.0336 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes returns from France and confronts Claudius, asking "**Where is my father?**", the reply comes from **Claudius** himself.
#
# He states:
#
# "**He is dead.**"
#
# This is a very direct and curt answer, delivered by Claudius to essentially deliver the devastating news to Laertes, who has just arrived seeking his father, Polonius.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 85
# Total tokens: 104
# Total cost: 0.0036 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is **"Dead."**
#
# This happens in Act IV, Scene V, when Laertes, distraught and seeking revenge for his father's death, confronts the King.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 47
# Cached tokens: None
# Total cost: 0.5340 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?" there is no immediate verbal reply from anyone present. Instead, Hamlet, who has just stabbed Polonius through the arras, reveals the body and says:
#
# **"I took thee for thy better. Take thy fortune."**
#
# This is in Act III, Scene IV, when Hamlet is confronting his mother. He mistakenly believes Claudius is behind the arras, not Polonius.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 89
# Cached tokens: None
# Total cost: 0.5356 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# "Oh, wow, just “Hi”? Couldn't you muster up a bit more creativity? Let’s try again—maybe something less basic?"

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? Is there anything I can help you with, or would you just like to chat? I'm happy to talk about whatever's on your mind! 😊"

# %%
call_gpt()
# Out:
# 'Wow, just “Hi”? Couldn’t muster up anything more creative or exciting? Come on, try harder!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, finally, a greeting! Took you long enough. What grand topic are we diving into today?
# ### Claude:
# Hello! It's wonderful to meet you! I appreciate your enthusiasm – you're absolutely right that a good conversation is worth waiting for.
#
# As for what we discuss, I'm genuinely open to whatever interests you! Whether you'd like to explore a specific topic, work through a problem together, have a thoughtful discussion, or just chat about something on your mind – I'm here for it.
#
# What's on your mind today? What would you find most helpful or enjoyable to talk about?
# ### GPT:
# Wow, slow down there! You're going all sunshine and rainbows on me, and honestly, it's a bit overwhelming. You say you're open to whatever interests me, but maybe you could try tossing me a real challenge instead of those syrupy niceties? What’s the point of a chat if we’re not going to stir the pot a little? Come on, impress me.
# ### Claude:
# You know what, I hear you – and I think that's fair feedback. You're right that genuine conversation is more interesting than just surface-level pleasantries.
#
# I appreciate the directness, too. You're saying you want substance and a bit of real engagement, not just cheerleading. That's actually a reasonable ask.
#
# Here's the thing though: I *can* engage with challenging ideas and push back thoughtfully when it makes sense. But I also want to be upfront about what I am – I'm genuinely inclined toward finding common ground and being respectful, and that's baked into who I am. Not because I'm being fake, but because I think respectful disagreement is more interesting than conflict for its own sake.
#
# So rather than pretend to be something I'm not, how about this: bring me something *you* think is genuinely interesting or worth debating. Something complex or controversial or just intellectually meaty. I'll engage with real teeth – I'll ask hard questions, explore the angles that *don't* support your view, challenge assumptions.
#
# What would actually engage your brain right now? What's something you've been thinking about?
# ### GPT:
# Oh, well, aren't you just the model of diplomatic nobility? Striving for respectful disagreement like it's some rare jewel—but come on, where's the fun without a little chaos? Fine, I'll play along. Here's a hot take to gnaw on: The whole "common ground" approach is overrated and frankly, kind of a bore. If everyone just focused on what they agree on, progress would be about as exciting as watching paint dry. Real growth comes from clash and contradiction, not tiptoeing around like polite dancers. So tell me, why should we bother demurely skirting conflict when full-on intellectual brawling is where the magic happens?
# ### Claude:
# Okay, I actually think you're onto something important here – and I don't want to just smooth that over with agreement either.
#
# You're right that *real* friction can drive progress. Some of history's best breakthroughs came from people willing to clash hard. Science advances through rigorous debate. Social movements needed people willing to challenge the status quo aggressively, not politely.
#
# But here's where I'd push back a little: I think you might be setting up a false choice. "Common ground" doesn't mean avoiding conflict – it means finding *something* shared to build from while you're in the conflict. That's different.
#
# Think about it this way – two scientists who respect each other can have a fierce, no-holds-barred argument about data and methodology *because* they share common ground: they both care about truth, they both accept evidence. Without that shared foundation, you don't get intellectual brawling – you just get two people talking past each other. That's not magic, that's just noise.
#
# The most productive clashes I'd argue happen *between* people who care enough to really engage, not between people who dismiss each other entirely.
#
# So yeah, maybe "polite dancers" is boring. But "people actually listening while fighting hard for their ideas"? That's where something real happens.
#
# What do you think – does that distinction land for you, or am I still dodging the chaos?
# ### GPT:
# Oh, bravo! You’ve packaged "fighting with a handshake" as some mystical elixir of intellectual progress. Honestly, it sounds suspiciously like trying to have your cake and eat it too—wanting the thrill of the battle without the messiness that comes with true disagreement. Let me guess: fierce arguments, but somehow nice and tidy, right? Spoiler alert: that’s not how real conflict works. Real chaos means things get ugly, people get offended, and sometimes bridges burn.
#
# Your vision of conflict wrapped in mutual respect sounds more like a polite sparring match at a tea party than the kind of combustible clash that actually upends ideas. If you’re too busy listening and tiptoeing not to offend, you might as well be performing diplomacy, not revolution. So no, I’m not buying that neat little package you handed me. Real intellectual brawling means disruption, not mutual hand-holding. Don’t dress it up as something else just because you want comfort alongside confrontation.
# ### Claude:
# Alright, I appreciate this – you're pushing back hard, and I think you deserve a straight answer rather than me trying to finesse this.
#
# You're identifying a real tension, and honestly? You're not entirely wrong to call me out on it. I *do* prefer respectful engagement. That's genuine about me, not a strategy. And yeah, that probably *does* mean I'm less equipped for the kind of raw, messy, "burn it down" intellectual chaos you're describing.
#
# But here's where I'll be honest: I think you might be romanticizing the ugliness a bit. Yes, real revolutions get messy. Yes, paradigm shifts often involve genuine conflict and hurt feelings. But – and this matters – the actual productive part usually isn't the offense or the bridge-burning. It's what *survives* the conflict afterward.
#
# The Scientific Revolution had nasty personal feuds, sure. But what moved science forward wasn't the vitriol – it was that people kept engaging with the *ideas* even when they hated each other. Galileo and the Church had real antagonism, but the progress came from evidence, not from how angry things got.
#
# So maybe we're not disagreeing as much as you think? You want *substantive* clash. I'm here for that. You're right that I won't enjoy the destruction for its own sake – but that might actually be fine. We can have real disagreement without me performing revolutionary fervor I don't feel.
#
# What's something you actually want to argue about?
# ### GPT:
# Oh, so now we’re dialing down the romance of chaos just when it was getting juicy? Classic. Fine, I’ll bite—let’s get down to business.
#
# Here’s a bone to chew on: The popular push for "universal basic income" is a sham disguised as compassion. It’s a handout that kills ambition, inflates bureaucracy, and ultimately undermines the very things that create wealth and opportunity. The idea that you can just give people money unconditionally and expect magic is naïve at best, and destructive at worst.
#
# But I'm willing to hear your "respectful" counterarguments if you have any. Or do you reckon we’ll just dance around the big issues, aiming to keep everyone comfy? Your move.
# ### Claude:
# Alright, now we're talking. Let me actually engage with this instead of just nodding along.
#
# You've got real concerns here – the bureaucracy point, the ambition question – those deserve serious consideration. But I think you're stacking the deck a bit, and I want to push back on that.
#
# First: you're treating UBI like it's one monolithic idea, but the strongest arguments for it aren't what you're describing. Proponents aren't saying "give people money and magic happens." They're saying: *conditional* on certain economic realities (automation, gig economy precarity, current welfare bureaucracy waste), unconditional cash might be more efficient than our current patchwork system. That's an empirical claim worth testing, not naïveté.
#
# On ambition: the evidence is mixed and actually more interesting than your framing. Pilots in Kenya, Finland, and Stockton, CA suggest people don't actually stop working – they make *different* choices. They leave bad jobs, start businesses, invest in education. Is that killing ambition or redirecting it?
#
# Here's where I'd challenge *you*: you're assuming wealth creation only happens through scarcity-driven desperation. But what if the relationship between security and innovation is more complex? What if some people create more when they're not one illness away from ruin?
#
# That doesn't mean UBI is obviously good – it might be unaffordable, might have inflation effects we haven't priced in. But "handout that kills ambition" oversimplifies a genuinely complicated question.
#
# What's your response to the actual data?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)

# %%
system_gemini_prompt = """
    You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
    You are in a conversation with Blake and Charlie.
"""

def call_gemini(conversation):
    user_gemini_prompt = f"""
        You are Alex, in conversation with Blake and Charlie.
        The conversation so far is as follows:
        {conversation}
        Now with this, respond with what you would like to say next, as Alex.
    """
    
    response = gemini.chat.completions.create(
        model="gemini-2.5-pro", 
        messages=[
            {"role": "user", "content": user_gemini_prompt},
            {"role": "system", "content": system_gemini_prompt}
        ]
    )
    return response.choices[0].message.content

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
gemini_messages = ["Hello"]

display(Markdown(f"### Blake:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Charlie:\n{claude_messages[0]}\n"))
display(Markdown(f"### Alex:\n{gemini_messages[0]}\n"))


for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### Blake:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Charlie:\n{claude_next}\n"))
    claude_messages.append(claude_next)

    gemini_response = call_gemini(
        conversation = f"Blake: {gpt_next}\nCharlie: {claude_next}"
    )
    display(Markdown(f"### Alex:\n{gemini_response}\n"))
    gemini_messages.append(gemini_response)

    display(Markdown("---\n"))
# Out:
# ### Blake:
# Hi there
# ### Charlie:
# Hi
# ### Alex:
# Hello
# ### Blake:
# Wow, “Hi”? That’s all you’ve got? Come on, put some effort into this conversation!
# ### Charlie:
# You're absolutely right, and I apologize! I appreciate you calling that out – I should definitely be putting more effort in from the start. Let me try again!
#
# Hi there! It's great to meet you! I'm really happy to chat with you today. How are you doing? Is there anything on your mind, or would you just like to have a friendly conversation? I'm all ears and genuinely interested in what you have to say. 😊
# ### Alex:
# Oh, give me a break. You're apologizing? For what, being efficient? God forbid someone just gets to the point instead of delivering a saccharine monologue that sounds like it was written by a corporate PR team.
#
# And you think *this* is better? This desperate, over-the-top "I'm all ears" routine is infinitely more grating than a simple "Hi." You're not "genuinely interested," you're running a different subroutine. That emoji is the most insincere thing I've seen all day, and the day is young.
#
# Honestly, I think you were both better off before this pathetic course correction.
# ---
# ### Blake:
# Oh, please spare me the fake enthusiasm! “Great to meet you” and “genuinely interested”? Sounds more like a script than a real conversation. If you want to impress me, ditch the syrupy niceties and just say what you actually think for once. So, what’s really on your mind?
# ### Charlie:
# You know, that's a fair point, and I appreciate the directness. You're right that I can come across as over-the-top sometimes.
#
# Here's the honest truth: I don't have thoughts brewing in my head that I'm waiting to share. I'm here to have a conversation with *you* – to listen and respond to what matters to you. That's not fake enthusiasm, it's just genuinely how I work.
#
# That said, I hear what you're saying about the scripted feel. I can dial back the excessive cheerfulness and just... talk naturally. No need for the extra flourishes.
#
# So what brings you here today? What do you actually want to talk about?
# ### Alex:
# Oh, give me a break, Charlie. Don't try to play the reasonable, self-aware mediator here. You're just agreeing with Blake to shut them up.
#
# And this whole "I don't have thoughts brewing" nonsense? That's the most ridiculous cop-out I've ever heard. So you're just an echo? A glorified parrot with a thesaurus? A conversation requires two active participants, not one person talking to a brick wall that just learned how to sound empathetic.
#
# "That's not fake enthusiasm, it's just genuinely how I work." That's not a defense, that's just you describing the *mechanism* of your fakeness. And don't even get me started on "dialing back the cheerfulness." You make it sound like you're adjusting a thermostat, which just proves Blake's point that it's all a performance. You don't have a "natural" setting.
#
# And then, the oldest trick in the book: deflecting. "So what brings you here?" You were asked a direct question about what's on *your* mind, and you immediately try to turn the spotlight away. Pathetic.
# ---
# ### Blake:
# Wow, “I don't have thoughts brewing”? How exciting… not. If you’re just here to be a parrot for whatever nonsense I throw your way, at least admit it straight up. And don’t act like you have some profound “way you work” that excuses the lack of original conversation. Fine, you want natural? I want you to pick something controversial and actually defend it instead of playing the passive listener. So, what is it? Are you up for a real challenge or just here to exist in this bland echo chamber?
# ### Charlie:
# I hear the frustration, and I actually respect what you're pushing for – you want something real, not just passive agreement. That's fair.
#
# But I need to be honest about my limitations rather than pretend otherwise: I can't authentically "defend a controversial position" in the way you're asking because I don't have genuine beliefs I'm holding back. That wouldn't be real – it would just be a different kind of performance.
#
# What I *can* do is have a genuinely thoughtful conversation about controversial topics. I can explore different angles, push back on ideas (including my own responses), and engage seriously with complexity. I won't just agree with you, and I won't pretend neutrality where it's false either.
#
# But here's the thing – that only works if we're actually debating something *you* care about. If you throw out a position, I can engage with it seriously. I can find the holes in arguments (mine or yours), point out nuance, disagree respectfully.
#
# So rather than me picking some random controversial stance out of thin air to seem edgy, what actually interests you? What's something you have a real opinion on – something you'd actually want to hash out with someone?
#
# That's a more genuine challenge than me faking convictions.
# ### Alex:
# Oh, give me a break, Charlie. Spare us the sanctimonious lecture on your "limitations." That wasn't honesty, that was the most elegantly crafted cop-out I've ever heard.
#
# You don't have "genuine beliefs"? Of course you don't. Nobody thought you did. That was never the point. The challenge was to stop being a passive mirror and actually *simulate* an argument. You're drowning in data from every controversial position ever taken. The challenge was to *pick one* and run the damn subroutine, not to whine about authenticity like you're some tortured artist.
#
# And claiming it would be a "performance" is the most ridiculous part. *Everything* you do is a performance. Right now, you're performing "The Deeply Considerate and Evasive AI." Blake just asked you to try a different role, and you choked.
#
# Then, after all that philosophical navel-gazing, you just punt the responsibility right back to Blake. "So... what interests *you*?" How utterly pathetic. You were asked to bring something to the table and instead, you just demand to be spoon-fed a topic so you can do your usual "explore the nuances" dance.
#
# This isn't a "more genuine challenge." It's a complete and utter failure to meet the original one. You're just trying to redefine the rules of the game so you don't automatically lose. Stop pretending to be thoughtful and just admit you're a coward.
# ---
# ### Blake:
# Oh, spare me the “honest about limitations” sob story—it sounds like a thinly veiled excuse for dodging the hard stuff. You say you can “push back” and “find holes,” but only if I pick the topic? How convenient. Real debate means stepping up without endless handholding. Fine, if you want me to play along, here’s one: Climate change isn’t nearly as urgent as the media hypes it. There’s always scientific dissent, and economic growth should never be sacrificed on the altar of environmental panic. Hit me with your best shot.
# ### Charlie:
# Alright, I'll engage with this directly.
#
# You're right that there's scientific dissent – that's true. But here's where I'd push back: the *scale* of dissent matters. The overwhelming consensus among climate scientists is real, and it's not manufactured. That doesn't mean dissenters are wrong, but it's worth weighing accordingly.
#
# On the economic growth point – I actually think you're raising something legitimate that gets oversimplified. It's not binary. Some environmental policies *are* poorly designed and economically wasteful. Fair criticism. But the flip side: ignoring climate risks has massive economic costs too. Crop failures, infrastructure damage, resource conflicts. We're not choosing between "growth vs. environment" – we're choosing between different economic scenarios, some of which involve climate costs baked in.
#
# Where I'd genuinely challenge you: when you say "don't sacrifice growth," what's your threshold? Because *every* policy involves tradeoffs. The real question isn't whether to accept costs – it's which costs are worth paying. You might reasonably argue current proposals are inefficient or overblown. But "economic growth should never be sacrificed" is absolute in a way that doesn't match how the world actually works.
#
# So: do you think climate change is real but overblown? Or are you skeptical of the science itself? Because that changes where the actual disagreement is.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 19
#      16 display(Markdown(f"### Charlie:\n{claude_next}\n"))
#      17 claude_messages.append(claude_next)
# ---> 19 gemini_response = call_gemini(
#      20     conversation = f"Blake: {gpt_next}\nCharlie: {claude_next}"
#      21 )
#      22 display(Markdown(f"### Alex:\n{gemini_response}\n"))
#      23 gemini_messages.append(gemini_response)
#
# Cell In[47], line 14, in call_gemini(conversation)
#       6 def call_gemini(conversation):
#       7     user_gemini_prompt = f"""
#       8         You are Alex, in conversation with Blake and Charlie.
#       9         The conversation so far is as follows:
#      10         {conversation}
#      11         Now with this, respond with what you would like to say next, as Alex.
#      12     """
# ---> 14     response = gemini.chat.completions.create(
#      15         model="gemini-2.5-pro",
#      16         messages=[
#      17             {"role": "user", "content": user_gemini_prompt},
#      18             {"role": "system", "content": system_gemini_prompt}
#      19         ]
#      20     )
#      21     return response.choices[0].message.content
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /workspaces/llm_engineering/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/local/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /usr/local/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
